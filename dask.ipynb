# %% [markdown]
# Testing using Dask with some of the big files and with HTTP file access.

# %%
import dask.array as da
import xarray as xr
import rioxarray as rxr

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster()          # Fully-featured local Dask cluster
client = cluster.get_client()

client
# Out:
# <Client: 'tcp://127.0.0.1:52289' processes=4 threads=8, memory=16.00 GiB>

# %%
nc_file = "data/gfs/gdas.t00z.sfcanl.nc"

ds = xr.open_dataset(nc_file, chunks="auto")

# %%
ds
client.close()
